# %% [markdown]
# <a href="https://colab.research.google.com/github/shaikhasif69/CoLab-Projects/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ds = pd.read_csv("cosmetics.csv")

# %%
ds.head()
# Out:
#          Label           Brand                                           Name  \
# 0  Moisturizer          LA MER                                Crème de la Mer
# 1  Moisturizer           SK-II                       Facial Treatment Essence
# 2  Moisturizer  DRUNK ELEPHANT                     Protini™ Polypeptide Cream
# 3  Moisturizer          LA MER                    The Moisturizing Soft Cream
# 4  Moisturizer    IT COSMETICS  Your Skin But Better™ CC+™ Cream with SPF 50+
#
#    Price  Rank                                        Ingredients  \
# 0    175   4.1  Algae (Seaweed) Extract, Mineral Oil, Petrolat...
# 1    179   4.1  Galactomyces Ferment Filtrate (Pitera), Butyle...
# 2     68   4.4  Water, Dicaprylyl Carbonate, Glycerin, Ceteary...
# 3    175   3.8  Algae (Seaweed) Extract, Cyclopentasiloxane, P...
# 4     38   4.1  Water, Snail Secretion Filtrate, Phenyl Trimet...
#
#    Combination  Dry  Normal  Oily  Sensitive
# 0            1    1       1     1          1
# ...

# %%
ds.sample(5)
# Out:
#             Label      Brand  \
# 182   Moisturizer   SMASHBOX
# 898     Face Mask  DR. JART+
# 981     Face Mask  DR. JART+
# 1048    Face Mask     BOSCIA
# 262   Moisturizer   SHISEIDO
#
#                                                    Name  Price  Rank  \
# 182   Camera Ready CC Cream Broad Spectrum SPF 30 Da...     42   3.9
# 898                          Shake & Shot™ Rubber Masks     12   4.1
# 981                              Firm Lover Rubber Mask     12   4.0
# 1048                Sake Brightening Bio-Cellulose Mask      8   4.3
# 262   Ibuki Protective Moisturizer Broad Spectrum SP...     45   3.9
#
#                                             Ingredients  Combination  Dry  \
# 182   Octinoxate 7.50%, Octisalate 4.00%, Oxybenzone...            1    1
# 898   -Vitamin C (Ascorbic Acid): Brightens the look...            1    1
# 981   Water, Methylpropanediol, Chondrus Crispus Ext...            1    1
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Label        1472 non-null   object
#  1   Brand        1472 non-null   object
#  2   Name         1472 non-null   object
#  3   Price        1472 non-null   int64
#  4   Rank         1472 non-null   float64
#  5   Ingredients  1472 non-null   object
#  6   Combination  1472 non-null   int64
#  7   Dry          1472 non-null   int64
#  8   Normal       1472 non-null   int64
#  9   Oily         1472 non-null   int64
#  10  Sensitive    1472 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 126.6+ KB

# %%
something = ds.columns
for i in something:
  print(i)
  if i == "Dry":
    print("dry got you!")
    break
# Out:
# Label
# Brand
# Name
# Price
# Rank
# Ingredients
# Combination
# Dry
# dry got you!

# %%
myArr = ds.columns.values


for i in myArr:
    if i == "Brand":
      print("Got you!")
      break
# Out:
# Got you!

# %%
ds.describe()
# Out:
#              Price         Rank  Combination          Dry       Normal  \
# count  1472.000000  1472.000000   1472.00000  1472.000000  1472.000000
# mean     55.584239     4.153261      0.65625     0.614130     0.652174
# std      45.014429     0.633918      0.47512     0.486965     0.476442
# min       3.000000     0.000000      0.00000     0.000000     0.000000
# 25%      30.000000     4.000000      0.00000     0.000000     0.000000
# 50%      42.500000     4.300000      1.00000     1.000000     1.000000
# 75%      68.000000     4.500000      1.00000     1.000000     1.000000
# max     370.000000     5.000000      1.00000     1.000000     1.000000
#
#               Oily    Sensitive
# count  1472.000000  1472.000000
# mean      0.607337     0.513587
# std       0.488509     0.499985
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       1.000000     1.000000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %%
ds.head(3)
# Out:
#          Label           Brand                        Name  Price  Rank  \
# 0  Moisturizer          LA MER             Crème de la Mer    175   4.1
# 1  Moisturizer           SK-II    Facial Treatment Essence    179   4.1
# 2  Moisturizer  DRUNK ELEPHANT  Protini™ Polypeptide Cream     68   4.4
#
#                                          Ingredients  Combination  Dry  \
# 0  Algae (Seaweed) Extract, Mineral Oil, Petrolat...            1    1
# 1  Galactomyces Ferment Filtrate (Pitera), Butyle...            1    1
# 2  Water, Dicaprylyl Carbonate, Glycerin, Ceteary...            1    1
#
#    Normal  Oily  Sensitive
# 0       1     1          1
# 1       1     1          1
# 2       1     1          0

# %%
print("hello!")
# Out:
# hello!

# %%
ds.isnull().sum().head(3)
# Out:
# Label    0
# Brand    0
# Name     0
# dtype: int64

# %%
ds[ds.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Label, Brand, Name, Price, Rank, Ingredients, Combination, Dry, Normal, Oily, Sensitive]
# Index: []

# %%
theShape = ds.shape
print("shape : ", theShape)
# Out:
# shape :  (1472, 11)

# %%
total_brand = ds["Brand"].unique()
print(type(total_brand))
# Out:
# <class 'numpy.ndarray'>

# %%
brand_max_price = ds.loc[ds["Price"].min(),["Label"]]
print("Brand with the highest price:", brand_max_price)

ds["Price"].min()
# Out:
# Brand with the highest price: Label    Moisturizer
# Name: 3, dtype: object
# 3

# %%
for_combination_skin = ds[ds["Combination"] == 1]["Brand"].nunique()
print(for_combination_skin)
# Out:
# 95

# %%
top_5_brands = ds["Brand"].value_counts().head(5)
# print(top_5_brands)

the_5_brands = ds.sort_values(by="Rank", ascending=True).head(5)["Brand"]
print(the_5_brands.to_list())
# Out:
# ['DERMAFLASH', 'KATE SOMERVILLE', 'BEAUTYBIO', 'CLINIQUE', 'DRUNK ELEPHANT']
